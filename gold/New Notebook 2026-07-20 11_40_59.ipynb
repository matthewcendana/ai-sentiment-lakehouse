# %%
# %sql
SELECT COUNT(*) AS scored_so_far FROM ai_tool_sentiment.gold.sentiment_scored;

# %%
# %sql
SELECT * FROM ai_tool_sentiment.bronze.producthunt_raw

# %%
# %sql
SELECT * FROM ai_tool_sentiment.silver.producthunt_clean
